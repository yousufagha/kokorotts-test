# %%
# !git clone https://huggingface.co/hexgrad/Kokoro-82M
# %cd Kokoro-82M
# Out:
# Cloning into 'Kokoro-82M'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 131 (delta 57), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (131/131), 57.13 KiB | 14.28 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Filtering content: 100% (17/17), 820.18 MiB | 44.20 MiB/s, done.
# /content/Kokoro-82M

# %%
# !apt-get -qq -y install espeak-ng > /dev/null 2>&1
# !pip install -q phonemizer torch transformers scipy munch
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.0/567.0 kB 30.2 MB/s eta 0:00:00
#   Building wheel for pylatexenc (setup.py) ... done

# %%
from models import build_model
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
MODEL = build_model('kokoro-v0_19.pth', device)

VOICE_NAME = ['af_bella',][0]

# VOICE_NAME = [
#     'af',
#     'af_bella', 'af_sarah', 'am_adam', 'am_michael',
#     'bf_emma', 'bf_isabella', 'bm_george', 'bm_lewis',][0]

VOICEPACK = torch.load(f'voices/{VOICE_NAME}.pt', weights_only=True).to(device)
print(f'Loaded voice: {VOICE_NAME}')
# Out:
# Loaded voice: af_bella

# %%
from kokoro import generate
text = "The naked man fears no pickpoket but he can also never carry a powerbank with him on the metro "
audio, out_ps = generate(MODEL, text, VOICEPACK, lang=VOICE_NAME[0])
# Out:
# WARNING:phonemizer:words count mismatch on 100.0% of the lines (1/1)

# %%
from IPython.display import display, Audio
display(Audio(data=audio, rate=24000, autoplay=True))
print(out_ps)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ðə nˈeɪkᵻd mˈæn fˈɪɹz nˈoʊ pˈɪkpɑːkɪt bˌʌt hiː kæn ˈɔːlsoʊ nˈɛvɚ kˈæɹi ɐ pˈaʊɚbˌæŋk wɪð hˌɪm ɔnðə mˈɛtɹoʊ
